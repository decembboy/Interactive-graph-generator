# %%
def bar():


  cube='''graph=plt.''' +option.value+'('+bar_1.value + ','+bar_2.value+')'

  exec(cube)

# %%
import pandas as pd
import os
import shutil
from matplotlib import pyplot as plt
from ipywidgets import widgets

# %%
psd=pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
psd=psd.head()

# %%
code='''=[]

for  in psd[]:
  .append()
'''

# %%
for i in psd:



  fnd=code.find('=')

  #print(fnd)


  #print(i+code[fnd:9]+i+code[9:17]+"'"+i+"'"+code[17:19]+code[19:22]+i+code[22:30]+i+code[30:])
  #print(i[:9]+code[fnd:9]+i+code[9:17]+"'"+i+"'"+code[17:19]+code[19:22]+i[:9]+code[22:30]+i+code[30:])
  function=i[:9]+code[fnd:9]+i+'s'+code[9:17]+"'"+i+"'"+code[17:19]+code[19:22]+i[:9]+code[22:30]+i+'s'+code[30:]
  #print(i[:9])
  exec(function)

# %%
mapping='''mapping={}
'''

# %%
li=[]

fnd=mapping.find('{')

for i in psd:
  text="'"+i+"'"+' : '+"'"+i[:9]+"'"+' , '
  #print(text)
  li.append(text)


string=""


for i in li:
  string+=i
print(mapping[0:9]+string+'}')

exec((mapping[0:9]+string+'}'))
# Out:
# mapping={'longitude' : 'longitude' , 'latitude' : 'latitude' , 'housing_median_age' : 'housing_m' , 'total_rooms' : 'total_roo' , 'total_bedrooms' : 'total_bed' , 'population' : 'populatio' , 'households' : 'household' , 'median_income' : 'median_in' , 'median_house_value' : 'median_ho' , }

# %%
drop=widgets.Dropdown(options=['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income','median_house_value'])
drop
# Out:
# Dropdown(options=('longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population'…

# %%
d=drop.value[0:9]

# %%
option=widgets.Dropdown(options=['plot','bar','scatter','barh'])

option
# Out:
# Dropdown(options=('plot', 'bar', 'scatter', 'barh'), value='plot')

# %%
graph='''graph=plt.'''+option.value+'''('''+str(d)+''')

graph'''


graph
# Out:
# 'graph=plt.bar(longitude)\n\ngraph'

# %%
fnd=graph.find('plot')

#print(graph[0:15]+d+graph[15:])


#print(graph[0:15]+d+graph[15:])

# %%
exec(graph)

# %%
li=[]

for i in psd:
  li.append(i)


bar_1 = widgets.Dropdown(options=li)

bar_2 = widgets.Dropdown(options=li)

# %%
bar_1
# Out:
# Dropdown(options=('longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population'…

# %%
bar_2
# Out:
# Dropdown(options=('longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population'…

# %%
cube='''graph=plt.''' +option.value+'('+bar_1.value + ','+bar_2.value+')'

exec(cube)
